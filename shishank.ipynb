# %% [markdown]
# <a href="https://colab.research.google.com/github/Shishankmustang10/Shishank_CMU/blob/main/shishank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
g

# %%
max_paid_leave_country = top_countries.loc[top_countries['Paid Leave Days'].idxmax()]
max_public_holidays_country = top_countries.loc[top_countries['Paid Public Holidays'].idxmax()]

print(f"According to the data, **{max_paid_leave_country['Country']}** has the maximum paid leave days and **{max_public_holidays_country['Country']}** has the maximum paid public holidays among the top 20 countries by total paid vacation days.")
# Out:
# According to the data, **Yemen** has the maximum paid leave days and **Iran** has the maximum paid public holidays among the top 20 countries by total paid vacation days.
